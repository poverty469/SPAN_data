# %%
import pandas as pd

# %%
data = pd.read_csv("~/Downloads/basicNeeds.csv")
data
# Out:
#     Legislative District  TANF and State Family Assistance  TANF Use Rate  \
# 0                      1                               703              0
# 1                      2                              2412              0
# 2                      3                              5635              0
# 3                      4                              2931              0
# 4                      5                               689              0
# 5                      6                              2643              0
# 6                      7                              2629              0
# 7                      8                              2997              0
# 8                      9                              2133              0
# 9                     10                              1212              0
# 10                    11                              2380              0
# 11                    12                              1946              0
# ...

# %%
with open('basicNeeds.json', 'w') as f:
    f.write(data.to_json(orient='records'))
